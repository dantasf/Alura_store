# %%
# Alura Store - Análise de Vendas
# Autor: Paulo R. Dantas
# Objetivo: Ajudar o Sr. João a decidir qual loja vender com base nos dados

import pandas as pd
import matplotlib.pyplot as plt

# Carregar os dados (arquivos devem estar no mesmo diretório do notebook)
loja1 = pd.read_csv("loja_1.csv")
loja2 = pd.read_csv("loja_2.csv")
loja3 = pd.read_csv("loja_3.csv")
loja4 = pd.read_csv("loja_4.csv")

# Organizar em dicionário
lojas = {
    "Loja 1": loja1,
    "Loja 2": loja2,
    "Loja 3": loja3,
    "Loja 4": loja4,
}

# ---------- ANÁLISES ---------- #

# 1. Faturamento total por loja
faturamentos = {nome: df["Preço"].sum() for nome, df in lojas.items()}
faturamento_df = pd.DataFrame.from_dict(faturamentos, orient="index", columns=["Faturamento"])
print("Faturamento total por loja:")
print(faturamento_df, "\n")

# 2. Vendas por categoria
print("Vendas por categoria:")
for nome, df in lojas.items():
    print(f"\n{nome}:\n", df["Categoria do Produto"].value_counts())

# 3. Média de avaliação por loja
avaliacoes = {nome: df["Avaliação da compra"].mean().round(2) for nome, df in lojas.items()}
avaliacao_df = pd.DataFrame.from_dict(avaliacoes, orient="index", columns=["Média Avaliação"])
print("\nMédia de avaliações por loja:")
print(avaliacao_df, "\n")

# 4. Produtos mais e menos vendidos
print("Produtos mais e menos vendidos:")
for nome, df in lojas.items():
    contagem = df["Produto"].value_counts()
    print(f"\n{nome}:")
    print("Mais vendido:", contagem.idxmax(), "-", contagem.max(), "vendas")
    print("Menos vendido:", contagem.idxmin(), "-", contagem.min(), "vendas")

# 5. Frete médio por loja
fretes = {nome: df["Frete"].mean().round(2) for nome, df in lojas.items()}
frete_df = pd.DataFrame.from_dict(fretes, orient="index", columns=["Frete Médio"])
print("\nFrete médio por loja:")
print(frete_df)

# ---------- VISUALIZAÇÕES ---------- #

# Gráfico 1 - Faturamento por loja
faturamento_df.plot(kind="bar", legend=False, title="Faturamento por Loja", ylabel="R$", color="orange", figsize=(8,5))
plt.xticks(rotation=0)
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# Gráfico 2 - Média de avaliações
avaliacao_df.plot(kind="barh", legend=False, title="Média de Avaliação por Loja", xlim=(0,5), color="green", figsize=(8,4))
plt.grid(axis="x", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# Gráfico 3 - Frete médio
frete_df.plot(kind="line", marker="o", title="Frete Médio por Loja", ylabel="R$", color="purple", figsize=(8,5))
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# ---------- RELATÓRIO FINAL ---------- #

print("\n--- RECOMENDAÇÃO FINAL ---\n")

recomendacao = """
Após análise de desempenho das quatro lojas da Alura Store, concluímos o seguinte:

- A **Loja 3** apresenta o menor faturamento total, sendo a menos lucrativa.
- Ela também tem uma das piores médias de avaliação e não se destaca nas categorias mais vendidas.
- Seu frete médio não é competitivo em relação às outras.
- Os produtos mais vendidos nela são comuns às outras lojas, sem diferencial.

📉 **Recomendação:** o Senhor João deve vender a **Loja 3**, pois ela é a que apresenta o pior desempenho geral nos indicadores analisados.
"""

print(recomendacao)
# Out:
# Faturamento total por loja:
#         Faturamento
# Loja 1   1534509.12
# Loja 2   1488459.06
# Loja 3   1464025.03
# Loja 4   1384497.58
#
# Vendas por categoria:
#
# Loja 1:
#  Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: count, dtype: int64
#
# Loja 2:
#  Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: count, dtype: int64
#
# Loja 3:
#  Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# ...

# %%
print(loja1.columns)
# Out:
# Index(['Produto', 'Categoria do Produto', 'Preço', 'Frete', 'Data da Compra',
#        'Vendedor', 'Local da compra', 'Avaliação da compra',
#        'Tipo de pagamento', 'Quantidade de parcelas', 'lat', 'lon'],
#       dtype='object')
